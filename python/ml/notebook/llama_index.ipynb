# %%
# %pip install llama-index llama-index-llms-ollama llama-index-embeddings-huggingface
from llama_index.core import VectorStoreIndex, SimpleDirectoryReader, Settings
from llama_index.embeddings.huggingface import HuggingFaceEmbedding
from llama_index.llms.ollama import Ollama

directory = '/Users/chandan/code/personal/github/docs/'
documents = SimpleDirectoryReader(directory).load_data()
# Out:
# Requirement already satisfied: llama-index in /Users/chandan/.virtualenvs/ml/lib/python3.9/site-packages (0.11.3)
# Requirement already satisfied: llama-index-llms-ollama in /Users/chandan/.virtualenvs/ml/lib/python3.9/site-packages (0.3.0)
# Collecting llama-index-embeddings-huggingface
#   Downloading llama_index_embeddings_huggingface-0.3.1-py3-none-any.whl.metadata (718 bytes)
# Requirement already satisfied: llama-index-agent-openai<0.4.0,>=0.3.0 in /Users/chandan/.virtualenvs/ml/lib/python3.9/site-packages (from llama-index) (0.3.0)
# Requirement already satisfied: llama-index-cli<0.4.0,>=0.3.0 in /Users/chandan/.virtualenvs/ml/lib/python3.9/site-packages (from llama-index) (0.3.0)
# Requirement already satisfied: llama-index-core<0.12.0,>=0.11.3 in /Users/chandan/.virtualenvs/ml/lib/python3.9/site-packages (from llama-index) (0.11.3)
# Requirement already satisfied: llama-index-embeddings-openai<0.3.0,>=0.2.0 in /Users/chandan/.virtualenvs/ml/lib/python3.9/site-packages (from llama-index) (0.2.3)
# Requirement already satisfied: llama-index-indices-managed-llama-cloud>=0.3.0 in /Users/chandan/.virtualenvs/ml/lib/python3.9/site-packages (from llama-index) (0.3.0)
# Requirement already satisfied: llama-index-legacy<0.10.0,>=0.9.48 in /Users/chandan/.virtualenvs/ml/lib/python3.9/site-packages (from llama-index) (0.9.48.post3)
# Requirement already satisfied: llama-index-llms-openai<0.3.0,>=0.2.0 in /Users/chandan/.virtualenvs/ml/lib/python3.9/site-packages (from llama-index) (0.2.0)
# Requirement already satisfied: llama-index-multi-modal-llms-openai<0.3.0,>=0.2.0 in /Users/chandan/.virtualenvs/ml/lib/python3.9/site-packages (from llama-index) (0.2.0)
# Requirement already satisfied: llama-index-program-openai<0.3.0,>=0.2.0 in /Users/chandan/.virtualenvs/ml/lib/python3.9/site-packages (from llama-index) (0.2.0)
# Requirement already satisfied: llama-index-question-gen-openai<0.3.0,>=0.2.0 in /Users/chandan/.virtualenvs/ml/lib/python3.9/site-packages (from llama-index) (0.2.0)
# Requirement already satisfied: llama-index-readers-file<0.3.0,>=0.2.0 in /Users/chandan/.virtualenvs/ml/lib/python3.9/site-packages (from llama-index) (0.2.0)
# Requirement already satisfied: llama-index-readers-llama-parse>=0.2.0 in /Users/chandan/.virtualenvs/ml/lib/python3.9/site-packages (from llama-index) (0.2.0)
# Requirement already satisfied: nltk>3.8.1 in /Users/chandan/.virtualenvs/ml/lib/python3.9/site-packages (from llama-index) (3.9.1)
# Requirement already satisfied: ollama>=0.3.0 in /Users/chandan/.virtualenvs/ml/lib/python3.9/site-packages (from llama-index-llms-ollama) (0.3.2)
# Requirement already satisfied: huggingface-hub>=0.19.0 in /Users/chandan/.virtualenvs/ml/lib/python3.9/site-packages (from huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (0.24.6)
# Requirement already satisfied: sentence-transformers>=2.6.1 in /Users/chandan/.virtualenvs/ml/lib/python3.9/site-packages (from llama-index-embeddings-huggingface) (3.0.1)
# Requirement already satisfied: filelock in /Users/chandan/.virtualenvs/ml/lib/python3.9/site-packages (from huggingface-hub>=0.19.0->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (3.15.4)
# Requirement already satisfied: fsspec>=2023.5.0 in /Users/chandan/.virtualenvs/ml/lib/python3.9/site-packages (from huggingface-hub>=0.19.0->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (2024.6.1)
# Requirement already satisfied: packaging>=20.9 in /Users/chandan/.virtualenvs/ml/lib/python3.9/site-packages (from huggingface-hub>=0.19.0->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in /Users/chandan/.virtualenvs/ml/lib/python3.9/site-packages (from huggingface-hub>=0.19.0->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (6.0.2)
# Requirement already satisfied: requests in /Users/chandan/.virtualenvs/ml/lib/python3.9/site-packages (from huggingface-hub>=0.19.0->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (2.32.3)
# Requirement already satisfied: tqdm>=4.42.1 in /Users/chandan/.virtualenvs/ml/lib/python3.9/site-packages (from huggingface-hub>=0.19.0->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (4.66.5)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /Users/chandan/.virtualenvs/ml/lib/python3.9/site-packages (from huggingface-hub>=0.19.0->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (4.12.2)
# Requirement already satisfied: aiohttp in /Users/chandan/.virtualenvs/ml/lib/python3.9/site-packages (from huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (3.10.5)
# Collecting minijinja>=1.0 (from huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface)
#   Downloading minijinja-2.2.0-cp38-abi3-macosx_10_12_x86_64.macosx_11_0_arm64.macosx_10_12_universal2.whl.metadata (8.8 kB)
# Requirement already satisfied: openai>=1.14.0 in /Users/chandan/.virtualenvs/ml/lib/python3.9/site-packages (from llama-index-agent-openai<0.4.0,>=0.3.0->llama-index) (1.43.0)
# Requirement already satisfied: SQLAlchemy>=1.4.49 in /Users/chandan/.virtualenvs/ml/lib/python3.9/site-packages (from SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.12.0,>=0.11.3->llama-index) (2.0.32)
# Requirement already satisfied: dataclasses-json in /Users/chandan/.virtualenvs/ml/lib/python3.9/site-packages (from llama-index-core<0.12.0,>=0.11.3->llama-index) (0.6.7)
# Requirement already satisfied: deprecated>=1.2.9.3 in /Users/chandan/.virtualenvs/ml/lib/python3.9/site-packages (from llama-index-core<0.12.0,>=0.11.3->llama-index) (1.2.14)
# Requirement already satisfied: dirtyjson<2.0.0,>=1.0.8 in /Users/chandan/.virtualenvs/ml/lib/python3.9/site-packages (from llama-index-core<0.12.0,>=0.11.3->llama-index) (1.0.8)
# Requirement already satisfied: httpx in /Users/chandan/.virtualenvs/ml/lib/python3.9/site-packages (from llama-index-core<0.12.0,>=0.11.3->llama-index) (0.27.2)
# Requirement already satisfied: nest-asyncio<2.0.0,>=1.5.8 in /Users/chandan/.virtualenvs/ml/lib/python3.9/site-packages (from llama-index-core<0.12.0,>=0.11.3->llama-index) (1.6.0)
# Requirement already satisfied: networkx>=3.0 in /Users/chandan/.virtualenvs/ml/lib/python3.9/site-packages (from llama-index-core<0.12.0,>=0.11.3->llama-index) (3.2.1)
# Requirement already satisfied: numpy<2.0.0 in /Users/chandan/.virtualenvs/ml/lib/python3.9/site-packages (from llama-index-core<0.12.0,>=0.11.3->llama-index) (1.26.4)
# Requirement already satisfied: pillow>=9.0.0 in /Users/chandan/.virtualenvs/ml/lib/python3.9/site-packages (from llama-index-core<0.12.0,>=0.11.3->llama-index) (10.4.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.0 in /Users/chandan/.virtualenvs/ml/lib/python3.9/site-packages (from llama-index-core<0.12.0,>=0.11.3->llama-index) (2.8.2)
# Requirement already satisfied: tenacity!=8.4.0,<9.0.0,>=8.2.0 in /Users/chandan/.virtualenvs/ml/lib/python3.9/site-packages (from llama-index-core<0.12.0,>=0.11.3->llama-index) (8.5.0)
# Requirement already satisfied: tiktoken>=0.3.3 in /Users/chandan/.virtualenvs/ml/lib/python3.9/site-packages (from llama-index-core<0.12.0,>=0.11.3->llama-index) (0.7.0)
# Requirement already satisfied: typing-inspect>=0.8.0 in /Users/chandan/.virtualenvs/ml/lib/python3.9/site-packages (from llama-index-core<0.12.0,>=0.11.3->llama-index) (0.9.0)
# Requirement already satisfied: wrapt in /Users/chandan/.virtualenvs/ml/lib/python3.9/site-packages (from llama-index-core<0.12.0,>=0.11.3->llama-index) (1.16.0)
# Requirement already satisfied: llama-cloud>=0.0.11 in /Users/chandan/.virtualenvs/ml/lib/python3.9/site-packages (from llama-index-indices-managed-llama-cloud>=0.3.0->llama-index) (0.0.15)
# Requirement already satisfied: pandas in /Users/chandan/.virtualenvs/ml/lib/python3.9/site-packages (from llama-index-legacy<0.10.0,>=0.9.48->llama-index) (2.2.2)
# Requirement already satisfied: beautifulsoup4<5.0.0,>=4.12.3 in /Users/chandan/.virtualenvs/ml/lib/python3.9/site-packages (from llama-index-readers-file<0.3.0,>=0.2.0->llama-index) (4.12.3)
# Requirement already satisfied: pypdf<5.0.0,>=4.0.1 in /Users/chandan/.virtualenvs/ml/lib/python3.9/site-packages (from llama-index-readers-file<0.3.0,>=0.2.0->llama-index) (4.3.1)
# Requirement already satisfied: striprtf<0.0.27,>=0.0.26 in /Users/chandan/.virtualenvs/ml/lib/python3.9/site-packages (from llama-index-readers-file<0.3.0,>=0.2.0->llama-index) (0.0.26)
# Requirement already satisfied: llama-parse>=0.4.0 in /Users/chandan/.virtualenvs/ml/lib/python3.9/site-packages (from llama-index-readers-llama-parse>=0.2.0->llama-index) (0.5.1)
# Requirement already satisfied: click in /Users/chandan/.virtualenvs/ml/lib/python3.9/site-packages (from nltk>3.8.1->llama-index) (8.1.7)
# Requirement already satisfied: joblib in /Users/chandan/.virtualenvs/ml/lib/python3.9/site-packages (from nltk>3.8.1->llama-index) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /Users/chandan/.virtualenvs/ml/lib/python3.9/site-packages (from nltk>3.8.1->llama-index) (2024.7.24)
# Requirement already satisfied: transformers<5.0.0,>=4.34.0 in /Users/chandan/.virtualenvs/ml/lib/python3.9/site-packages (from sentence-transformers>=2.6.1->llama-index-embeddings-huggingface) (4.44.2)
# Requirement already satisfied: torch>=1.11.0 in /Users/chandan/.virtualenvs/ml/lib/python3.9/site-packages (from sentence-transformers>=2.6.1->llama-index-embeddings-huggingface) (2.4.0)
# Requirement already satisfied: scikit-learn in /Users/chandan/.virtualenvs/ml/lib/python3.9/site-packages (from sentence-transformers>=2.6.1->llama-index-embeddings-huggingface) (1.5.1)
# Requirement already satisfied: scipy in /Users/chandan/.virtualenvs/ml/lib/python3.9/site-packages (from sentence-transformers>=2.6.1->llama-index-embeddings-huggingface) (1.13.1)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /Users/chandan/.virtualenvs/ml/lib/python3.9/site-packages (from aiohttp->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (2.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /Users/chandan/.virtualenvs/ml/lib/python3.9/site-packages (from aiohttp->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /Users/chandan/.virtualenvs/ml/lib/python3.9/site-packages (from aiohttp->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/chandan/.virtualenvs/ml/lib/python3.9/site-packages (from aiohttp->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/chandan/.virtualenvs/ml/lib/python3.9/site-packages (from aiohttp->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /Users/chandan/.virtualenvs/ml/lib/python3.9/site-packages (from aiohttp->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /Users/chandan/.virtualenvs/ml/lib/python3.9/site-packages (from aiohttp->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (4.0.3)
# Requirement already satisfied: soupsieve>1.2 in /Users/chandan/.virtualenvs/ml/lib/python3.9/site-packages (from beautifulsoup4<5.0.0,>=4.12.3->llama-index-readers-file<0.3.0,>=0.2.0->llama-index) (2.6)
# Requirement already satisfied: anyio in /Users/chandan/.virtualenvs/ml/lib/python3.9/site-packages (from httpx->llama-index-core<0.12.0,>=0.11.3->llama-index) (4.4.0)
# Requirement already satisfied: certifi in /Users/chandan/.virtualenvs/ml/lib/python3.9/site-packages (from httpx->llama-index-core<0.12.0,>=0.11.3->llama-index) (2024.7.4)
# Requirement already satisfied: httpcore==1.* in /Users/chandan/.virtualenvs/ml/lib/python3.9/site-packages (from httpx->llama-index-core<0.12.0,>=0.11.3->llama-index) (1.0.5)
# Requirement already satisfied: idna in /Users/chandan/.virtualenvs/ml/lib/python3.9/site-packages (from httpx->llama-index-core<0.12.0,>=0.11.3->llama-index) (3.8)
# Requirement already satisfied: sniffio in /Users/chandan/.virtualenvs/ml/lib/python3.9/site-packages (from httpx->llama-index-core<0.12.0,>=0.11.3->llama-index) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in /Users/chandan/.virtualenvs/ml/lib/python3.9/site-packages (from httpcore==1.*->httpx->llama-index-core<0.12.0,>=0.11.3->llama-index) (0.14.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /Users/chandan/.virtualenvs/ml/lib/python3.9/site-packages (from openai>=1.14.0->llama-index-agent-openai<0.4.0,>=0.3.0->llama-index) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in /Users/chandan/.virtualenvs/ml/lib/python3.9/site-packages (from openai>=1.14.0->llama-index-agent-openai<0.4.0,>=0.3.0->llama-index) (0.5.0)
# Requirement already satisfied: annotated-types>=0.4.0 in /Users/chandan/.virtualenvs/ml/lib/python3.9/site-packages (from pydantic<3.0.0,>=2.7.0->llama-index-core<0.12.0,>=0.11.3->llama-index) (0.7.0)
# Requirement already satisfied: pydantic-core==2.20.1 in /Users/chandan/.virtualenvs/ml/lib/python3.9/site-packages (from pydantic<3.0.0,>=2.7.0->llama-index-core<0.12.0,>=0.11.3->llama-index) (2.20.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/chandan/.virtualenvs/ml/lib/python3.9/site-packages (from requests->huggingface-hub>=0.19.0->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/chandan/.virtualenvs/ml/lib/python3.9/site-packages (from requests->huggingface-hub>=0.19.0->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (2.2.2)
# Requirement already satisfied: greenlet!=0.4.17 in /Users/chandan/.virtualenvs/ml/lib/python3.9/site-packages (from SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.12.0,>=0.11.3->llama-index) (3.0.3)
# Requirement already satisfied: sympy in /Users/chandan/.virtualenvs/ml/lib/python3.9/site-packages (from torch>=1.11.0->sentence-transformers>=2.6.1->llama-index-embeddings-huggingface) (1.13.2)
# Requirement already satisfied: jinja2 in /Users/chandan/.virtualenvs/ml/lib/python3.9/site-packages (from torch>=1.11.0->sentence-transformers>=2.6.1->llama-index-embeddings-huggingface) (3.1.4)
# Requirement already satisfied: safetensors>=0.4.1 in /Users/chandan/.virtualenvs/ml/lib/python3.9/site-packages (from transformers<5.0.0,>=4.34.0->sentence-transformers>=2.6.1->llama-index-embeddings-huggingface) (0.4.4)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /Users/chandan/.virtualenvs/ml/lib/python3.9/site-packages (from transformers<5.0.0,>=4.34.0->sentence-transformers>=2.6.1->llama-index-embeddings-huggingface) (0.19.1)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /Users/chandan/.virtualenvs/ml/lib/python3.9/site-packages (from typing-inspect>=0.8.0->llama-index-core<0.12.0,>=0.11.3->llama-index) (1.0.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /Users/chandan/.virtualenvs/ml/lib/python3.9/site-packages (from dataclasses-json->llama-index-core<0.12.0,>=0.11.3->llama-index) (3.22.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/chandan/.virtualenvs/ml/lib/python3.9/site-packages (from pandas->llama-index-legacy<0.10.0,>=0.9.48->llama-index) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/chandan/.virtualenvs/ml/lib/python3.9/site-packages (from pandas->llama-index-legacy<0.10.0,>=0.9.48->llama-index) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /Users/chandan/.virtualenvs/ml/lib/python3.9/site-packages (from pandas->llama-index-legacy<0.10.0,>=0.9.48->llama-index) (2024.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /Users/chandan/.virtualenvs/ml/lib/python3.9/site-packages (from scikit-learn->sentence-transformers>=2.6.1->llama-index-embeddings-huggingface) (3.5.0)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /Users/chandan/.virtualenvs/ml/lib/python3.9/site-packages (from anyio->httpx->llama-index-core<0.12.0,>=0.11.3->llama-index) (1.2.2)
# Requirement already satisfied: six>=1.5 in /Users/chandan/.virtualenvs/ml/lib/python3.9/site-packages (from python-dateutil>=2.8.2->pandas->llama-index-legacy<0.10.0,>=0.9.48->llama-index) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/chandan/.virtualenvs/ml/lib/python3.9/site-packages (from jinja2->torch>=1.11.0->sentence-transformers>=2.6.1->llama-index-embeddings-huggingface) (2.1.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/chandan/.virtualenvs/ml/lib/python3.9/site-packages (from sympy->torch>=1.11.0->sentence-transformers>=2.6.1->llama-index-embeddings-huggingface) (1.3.0)
# Downloading llama_index_embeddings_huggingface-0.3.1-py3-none-any.whl (8.6 kB)
# Downloading minijinja-2.2.0-cp38-abi3-macosx_10_12_x86_64.macosx_11_0_arm64.macosx_10_12_universal2.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 11.0 MB/s eta 0:00:00
# Installing collected packages: minijinja, llama-index-embeddings-huggingface
# Successfully installed llama-index-embeddings-huggingface-0.3.1 minijinja-2.2.0
# Note: you may need to restart the kernel to use updated packages.

# %%
print(documents)
# Out:
# [Document(id_='62e6bfd6-80ec-4c38-98b5-7229a0f01182', embedding=None, metadata={'file_path': '/Users/chandan/code/personal/github/docs/0001_todos.md', 'file_name': '0001_todos.md', 'file_size': 566, 'creation_date': '2024-03-27', 'last_modified_date': '2024-03-27'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, text='\n\nTODOS\n', mimetype='text/plain', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'), Document(id_='743c0bde-20e8-4f96-b07d-00a95c52d956', embedding=None, metadata={'file_path': '/Users/chandan/code/personal/github/docs/0001_todos.md', 'file_name': '0001_todos.md', 'file_size': 566, 'creation_date': '2024-03-27', 'last_modified_date': '2024-03-27'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, text='\n\nTechnical Growth\n\n- [ ] Ollama\n  - [ ] Run something locally\n  - [ ] Do something on Collab\n- [ ] Figure out Azure courses from Architechture perspective\n  - [ ] Complete at least 2 courses\n  - [ ] Get a certificate\n- [ ] Read and make notes of Application Design and Architechture\n- [ ] Get comfortable with nvim\n- [ ] learn a new programming language\n- [ ] Build something using SQLite\n- [ ] Build a Website out of these MD files\n', mimetype='text/plain', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'), Document(id_='71a1a986-fe8b-4a03-b1ff-a4dc0c7eac06', embedding=None, metadata={'file_path': '/Users/chandan/code/personal/github/docs/0001_todos.md', 'file_name': '0001_todos.md', 'file_size': 566, 'creation_date': '2024-03-27', 'last_modified_date': '2024-03-27'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, text='\n\nPersonal Growth\n\n- [ ] Read 1 book every month\n- [x] Learn Swimming\n- [ ] Migrate notes from elsewhere to Github docs\n', mimetype='text/plain', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'), Document(id_='d8fddcf5-0f0e-4c0d-98c6-06fa39d75075', embedding=None, metadata={'file_path': '/Users/chandan/code/personal/github/docs/003-general-notes.md', 'file_name': '003-general-notes.md', 'file_size': 686, 'creation_date': '2024-03-01', 'last_modified_date': '2024-03-01'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, text='Quotes:\n\nThere is no user manual to life. Problems come first, and wisdom to handle those comes later when we go through failures.\n\nThis is by design. Because we learn the most by solving problems and overcoming failures.\n\n— Swami Mukandananda\n\nhttps://chat.openai.com/share/ee902dd9-fbdf-49a8-ac93-fd72f4502265\n\nI want structured information on Application Logging. Best practice around it. For example how do I log an important event for audit purpose, or a fatal error for reporting etc..\n\n---\n\nKartik Suryanarayan\n\nBusiness Relationship Manager (APAC)\nTata Consultancy Services\n60 Anson Road #18-01 Mapletree Anson\nSingapore - 079914\nCell:- +65 85187127\n ...

# %%
# bge-base embedding model
Settings.embed_model = HuggingFaceEmbedding(model_name="BAAI/bge-base-en-v1.5")

# ollama
Settings.llm = Ollama(model="tinyllama", request_timeout=360.0)

index = VectorStoreIndex.from_documents(
    documents,
)

# %%
print(index)
# Out:
# <llama_index.core.indices.vector_store.base.VectorStoreIndex object at 0x2a62e6250>

# %%
query_engine = index.as_query_engine()
response = query_engine.query("summarize Tmux for me")
print(response)
# Out:
# To summarize Tmux for you, here's an example of how to use the provided context information:
#
# 1. Avail yourself of the provided context by skipping the statement directly referencing the given context in your answer.
# 2. Use the provided rules to follow when answering the question. In this case, avoid direct statements like "Baseed on the context, ..." or "The context information...", instead use a more concise and intuitive explanation.
